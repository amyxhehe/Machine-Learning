# %%
x1 = 4
x2 = 5
x3 = 8
x4 = 1

w1 = 0.2
w2 = 0.4
w3 = 0.6
w4 = 0

r1 = x1*w1
r2 = x2*w2
r3 = x3*w3
r4 = x4*w4

b = 1

final_result = (r1 + r2 + r3 + r4) + b

print(final_result)

if final_result > 5:
  print("Hi.")
else:
  print("Bye.")
# Out:
# 8.6
# Hi.

# %%
x1 = 0.4
x2 = 0.3
x3 = 0.7
x4 = 0.6

#input 1 weights
w1 = 0.05
w2 = 0.10
w3 = 0.15
w4 = 0.20
w5 = 0.25

#input 2 weights
w6 = 0.30
w7 = 0.35
w8 = 0.40
w9 = 0.45
w10 = 0.50

#input 3 weights
w11 = 0.55
w12 = 0.60
w13 = 0.65
w14 = 0.70
w15 = 0.75

#input 4 weights
w16 = 0.80
w17 = 0.85
w18 = 0.90
w19 = 0.95
w20 = 1

h1_cell1 = x1*w1 + x2*w6 + x3*w11 + x4*w16
h1_cell2 = x1*w2 + x2*w7 + x3*w12 + x4*w17
h1_cell3 = x1*w3 + x2*w8 + x3*w13 + x4*w18
h1_cell4 = x1*w4 + x2*w9 + x3*w14 + x4*w19
h1_cell5 = x1*w5 + x2*w10 + x3*w15 + x4*w20

print("Hidden layer 1:")
print(h1_cell1)
print(h1_cell2)
print(h1_cell3)
print(h1_cell4)
print(h1_cell5)
# Out:
# Hidden layer 1:
# 0.975
# 1.075
# 1.175
# 1.275
# 1.375

# %%
x5 = h1_cell1
x6 = h1_cell2
x7 = h1_cell3
x8 = h1_cell4
x9 = h1_cell5

#input 1 weights
w21 = 1.05
w22 = 1.10
w23 = 1.15
w24 = 1.20
w25 = 1.25

#input 2 weights
w26 = 1.30
w27 = 1.35
w28 = 1.40
w29 = 1.45
w30 = 1.50

#input 3 weights
w31 = 1.55
w32 = 1.60
w33 = 1.65
w34 = 1.70
w35 = 1.75

#input 4 weights
w36 = 1.80
w37 = 1.85
w38 = 1.90
w39 = 1.95
w40 = 2

#input 5 weights
w41 = 2.05
w42 = 2.10
w43 = 2.15
w44 = 2.20
w45 = 2.25


h2_cell1 = x5*w21 + x6*w26 + x7*w31 + x8*w36 + x9*w41
h2_cell2 = x5*w22 + x6*w27 + x7*w32 + x8*w37 + x9*w42
h2_cell3 = x5*w23 + x6*w28 + x7*w33 + x8*w38 + x9*w43
h2_cell4 = x5*w24 + x6*w29 + x7*w34 + x8*w39 + x9*w44
h2_cell5 = x5*w25 + x6*w30 + x7*w35 + x8*w40 + x9*w45

print("Hidden layer 2:")
print(h2_cell1)
print(h2_cell2)
print(h2_cell3)
print(h2_cell4)
print(h2_cell5)
# Out:
# Hidden layer 2:
# 9.35625
# 9.649999999999999
# 9.943749999999998
# 10.2375
# 10.53125

# %%
x10 = h2_cell1
x11 = h2_cell2
x12 = h2_cell3
x13 = h2_cell4
x14 = h2_cell5

#input 1 weights
w46 = 2.30
w47 = 2.35
w48 = 2.40
w49 = 2.45
w50 = 2.50

#input 2 weights
w51 = 2.55
w52 = 2.60
w53 = 2.65
w54 = 2.70
w55 = 2.75

#input 3 weights
w56 = 2.80
w57 = 2.85
w58 = 2.90
w59 = 2.95
w60 = 3.0

#input 4 weights
w61 = 3.05
w62 = 3.10
w63 = 3.15
w64 = 3.20
w65 = 3.25

#input 5 weights
w66 = 3.30
w67 = 3.35
w68 = 3.40
w69 = 3.45
w70 = 3.50


h3_cell1 = x10*w46 + x11*w51 + x12*w56 + x13*w61 + x14*w66
h3_cell2 = x10*w47 + x11*w52 + x12*w57 + x13*w62 + x14*w67
h3_cell3 = x10*w48 + x11*w53 + x12*w58 + x13*w63 + x14*w68
h3_cell4 = x10*w49 + x11*w54 + x12*w59 + x13*w64 + x14*w69
h3_cell5 = x10*w50 + x11*w55 + x12*w60 + x13*w65 + x14*w70

print("Hidden layer 3:")
print(h3_cell1)
print(h3_cell2)
print(h3_cell3)
print(h3_cell4)
print(h3_cell5)
# Out:
# Hidden layer 3:
# 139.94687499999998
# 142.43281249999998
# 144.91875
# 147.4046875
# 149.890625

# %%
x15 = h3_cell1
x16 = h3_cell2
x17 = h3_cell3
x18 = h3_cell4
x19 = h3_cell5

#input 1 weights
w71 = 1.05
w72 = 1.10
w73 = 1.15
w74 = 1.20
w75 = 1.25

#input 2 weights
w76 = 1.30
w77 = 1.35
w78 = 1.40
w79 = 1.45
w80 = 1.50

#input 3 weights
w81 = 1.55
w82 = 1.60
w83 = 1.65
w84 = 1.70
w85 = 1.75

#input 4 weights
w86 = 1.80
w87 = 1.85
w88 = 1.90
w89 = 1.95
w90 = 2

#input 5 weights
w91 = 2.05
w92 = 2.10
w93 = 2.15
w94 = 2.20
w95 = 2.25


h4_cell1 = x15*w71 + x16*w76 + x17*w81 + x18*w86 + x19*w91
h4_cell2 = x15*w72 + x16*w77 + x17*w82 + x18*w87 + x19*w92
h4_cell3 = x15*w73 + x16*w78 + x17*w83 + x18*w88 + x19*w93
h4_cell4 = x15*w74 + x16*w79 + x17*w84 + x18*w89 + x19*w94
h4_cell5 = x15*w75 + x16*w80 + x17*w85 + x18*w90 + x19*w95

print("Hidden layer 4:")
print(h4_cell1)
print(h4_cell2)
print(h4_cell3)
print(h4_cell4)
print(h4_cell5)
# Out:
# Hidden layer 4:
# 1129.33515625
# 1165.56484375
# 1201.7945312499999
# 1238.02421875
# 1274.25390625

# %%
x20 = h4_cell1
x21 = h4_cell2
x22 = h4_cell3
x23 = h4_cell4
x24 = h4_cell5

#output weights
w96 = 0.00005
w97 = 0.00010
w98 = 0.00015
w99 = 0.00020
w100 = 0.00025

output_cell = x20*w96 + x21*w97 + x22*w98 + x23*w99 + x24*w100

print("Output:")
print(output_cell)
# Out:
# Output:
# 0.9194607421875001
